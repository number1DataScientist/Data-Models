# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Desktop/Data Science Files/JUB files/all files/car data.csv')

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
#scatterplot
plt.figure(figsize=(20, 25))
plotnumber = 1
for column in data.columns:
    plt.subplot(6, 4, plotnumber)
    sns.scatterplot(x=data[column], y=data['Selling_Price'])
    plt.xlabel(column, fontsize=20)
    plt.ylabel('Selling_Price', fontsize=20)
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
#histplot
plt.figure(figsize=(20, 25))
plotnumber = 1
for column in data.columns:
    plt.subplot(6, 4, plotnumber)
    sns.histplot(x=data[column],kde=True)
    plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
data2=data[['Year','Selling_Price','Present_Price','Kms_Driven']]

# %%
#boxplot
plt.figure(figsize=(20, 25))
plotnumber = 1
for column in data2.columns:
    plt.subplot(4, 4, plotnumber)
    sns.boxplot(x=data2[column])
    plt.xlabel(column, fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %%
sns.heatmap(data2.corr(),annot=True)
# Out:
# <Axes: >

# %%
data2.corr()
# Out:
#                    Year  Selling_Price  Present_Price  Kms_Driven
# Year           1.000000       0.236141      -0.047584   -0.524342
# Selling_Price  0.236141       1.000000       0.878983    0.029187
# Present_Price -0.047584       0.878983       1.000000    0.203647
# Kms_Driven    -0.524342       0.029187       0.203647    1.000000

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
data.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
data.Seller_Type.unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
data.Fuel_Type=data.Fuel_Type.map({'Petrol':int(2),'Diesel':int(1),'CNG':int(0)})

# %%
data.Transmission=data.Transmission.map({'Manual':int(1),'Automatic':int(0)})

# %%
data.Seller_Type=data.Seller_Type.map({'Dealer':int(1),'Individual':int(0)})

# %%
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Seller_Type  Transmission  Owner
# 0              1             1      0
# ...

# %%
X=data.iloc[:,1:]
X
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0    2014           3.35           5.59       27000          2            1
# 1    2013           4.75           9.54       43000          1            1
# 2    2017           7.25           9.85        6900          2            1
# 3    2011           2.85           4.15        5200          2            1
# 4    2014           4.60           6.87       42450          1            1
# ..    ...            ...            ...         ...        ...          ...
# 296  2016           9.50          11.60       33988          1            1
# 297  2015           4.00           5.90       60000          2            1
# 298  2009           3.35          11.00       87934          2            1
# 299  2017          11.50          12.50        9000          1            1
# 300  2016           5.30           5.90        5464          2            1
#
#      Transmission  Owner
# 0               1      0
# ...

# %%
x=X.drop('Selling_Price',axis=1)
x
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 0    2014           5.59       27000          2            1             1
# 1    2013           9.54       43000          1            1             1
# 2    2017           9.85        6900          2            1             1
# 3    2011           4.15        5200          2            1             1
# 4    2014           6.87       42450          1            1             1
# ..    ...            ...         ...        ...          ...           ...
# 296  2016          11.60       33988          1            1             1
# 297  2015           5.90       60000          2            1             1
# 298  2009          11.00       87934          2            1             1
# 299  2017          12.50        9000          1            1             1
# 300  2016           5.90        5464          2            1             1
#
#      Owner
# 0        0
# 1        0
# 2        0
# 3        0
# ...

# %%
y=data.iloc[:,2]
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %%
#from sklearn.datasets import make_regression
#x, y = make_regression(n_samples=10, n_features=1, noise=0.1, random_state=42)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      Year  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  \
# 184  2008          0.750       26000          2            0             1
# 132  2017          0.950        3500          2            0             1
# 194  2008          0.787       50000          2            0             1
# 75   2015          6.800       36000          2            1             1
# 111  2016          1.500        8700          2            0             1
# ..    ...            ...         ...        ...          ...           ...
# 188  2013          0.570       18000          2            0             1
# 71   2011         12.480       45000          1            1             1
# 106  2014          3.450       16500          2            0             1
# 270  2011         10.000       69341          2            1             1
# 102  2017          1.780        4000          2            0             1
#
#      Owner
# 184      1
# 132      0
# 194      0
# 75       0
# ...

# %%
y_train
# Out:
# 184    0.25
# 132    0.75
# 194    0.20
# 75     3.95
# 111    1.15
#        ...
# 188    0.25
# 71     4.50
# 106    1.35
# 270    4.10
# 102    1.65
# Name: Selling_Price, Length: 240, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf', C=1.0, gamma='scale')  # You can adjust hyperparameters as needed
svr.fit(X_train_scaled, y_train)
# Out:
# SVR()

# %%
y_test
# Out:
# 177     0.35
# 289    10.11
# 228     4.95
# 198     0.15
# 60      6.95
#        ...
# 234     5.50
# 296     9.50
# 281     2.10
# 285     7.40
# 182     0.30
# Name: Selling_Price, Length: 61, dtype: float64

# %%
#from sklearn.svm import SVR
#SVR=SVR(kernel='linear')
#SVR.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_predict=svr.predict(X_test_scaled)

# %%
y_predict
# Out:
# array([ 0.74890998,  8.60852833,  5.0457515 ,  0.38724266,  8.25324727,
#         6.47637545,  0.70808224,  0.65571109,  0.63664751,  6.45325753,
#         7.56646229,  0.54066663,  6.73155492,  0.83958253,  5.68663448,
#         2.89571491,  0.75775385, 10.14527205,  0.82175055,  1.25123854,
#         0.53871088,  7.2037136 ,  5.21206605,  2.76331422,  0.51244249,
#         3.59989853,  4.96893839,  2.69149009,  1.0481445 ,  0.86772593,
#         0.50331359,  7.87703141,  0.38960474,  2.05667708,  7.65019341,
#         4.59106096,  6.27332888,  4.78031036,  2.78954436,  5.64490289,
#         2.61138318,  2.96535419,  4.57621621,  0.42838857,  6.41594162,
#         0.47870217,  7.37583783,  5.55262802,  3.21299042,  4.07334671,
#         5.4531318 ,  1.12099253, 12.65309655, 12.34924727,  6.43246938,
#         7.83442581,  4.81159867,  8.08948213,  1.91384279,  6.22729301,
#         0.34202232])

# %%
y_test
# Out:
# 177     0.35
# 289    10.11
# 228     4.95
# 198     0.15
# 60      6.95
#        ...
# 234     5.50
# 296     9.50
# 281     2.10
# 285     7.40
# 182     0.30
# Name: Selling_Price, Length: 61, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mean_squared_error=mean_squared_error(y_test,y_predict)
mean_squared_error
# Out:
# 5.177923403343882

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error

svr = SVR()

param_grid = {
    'kernel': ['linear', 'rbf'],  
    'C': [0.1, 1, 10],             
    'epsilon': [0.1, 0.2, 0.5]     
}

grid_search = GridSearchCV(estimator=svr, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', verbose=2)
grid_search.fit(X_train_scaled, y_train) 

best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

best_model = grid_search.best_estimator_

y_pred = best_model.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   0.0s
# [CV] END ..................C=0.1, epsilon=0.1, kernel=linear; total time=   0.0s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, epsilon=0.1, kernel=rbf; total time=   0.0s
# [CV] END ..................C=0.1, epsilon=0.2, kernel=linear; total time=   0.0s
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from scipy.stats import uniform, randint

svr = SVR()

param_dist = {
    'kernel': ['linear', 'rbf'],                    
    'C': uniform(0.1, 10),                            
    'epsilon': uniform(0.1, 0.5)                      
}

random_search = RandomizedSearchCV(estimator=svr, param_distributions=param_dist, n_iter=10, cv=5, scoring='neg_mean_squared_error', verbose=2, random_state=42)
random_search.fit(X_train_scaled, y_train)  

best_params = random_search.best_params_
print("Best Hyperparameters:", best_params)

best_model = random_search.best_estimator_

y_pred = best_model.predict(X_test_scaled)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END C=3.845401188473625, epsilon=0.5753571532049581, kernel=linear; total time=   0.0s
# [CV] END C=3.845401188473625, epsilon=0.5753571532049581, kernel=linear; total time=   0.0s
# [CV] END C=3.845401188473625, epsilon=0.5753571532049581, kernel=linear; total time=   0.0s
# [CV] END C=3.845401188473625, epsilon=0.5753571532049581, kernel=linear; total time=   0.0s
# [CV] END C=3.845401188473625, epsilon=0.5753571532049581, kernel=linear; total time=   0.0s
# [CV] END C=7.896910002727692, epsilon=0.39842507897324353, kernel=rbf; total time=   0.0s
# [CV] END C=7.896910002727692, epsilon=0.39842507897324353, kernel=rbf; total time=   0.0s
# [CV] END C=7.896910002727692, epsilon=0.39842507897324353, kernel=rbf; total time=   0.0s
# [CV] END C=7.896910002727692, epsilon=0.39842507897324353, kernel=rbf; total time=   0.0s
# [CV] END C=7.896910002727692, epsilon=0.39842507897324353, kernel=rbf; total time=   0.0s
# ...
